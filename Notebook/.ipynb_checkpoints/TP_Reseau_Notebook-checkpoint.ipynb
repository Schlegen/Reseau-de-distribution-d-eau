# %% [markdown]
# # Travaux pratiques sur les réseaux d'eau

# %% [markdown]
# ## 0. Données et fonctions du problème

# %% [markdown]
# ### On charge dans l'environnement :
# 1. les fonctions de Python qui seront utilisées,
# 2. les données du problème,
# 3. les fonctions utilitaires du problème.

# %%
from numpy import random
import numpy as np
from numpy.linalg import norm

# %%
from Probleme_R import *
from Structures_N import *

# %%
from Visualg import Visualg
from Verification import Verification

# %% [markdown]
# ###  On charge les prototypes d'algorithmes d'optimisation :
#
# * **Gradient_F** : algorithme de gradient à pas fixe,
# * **Newton_F** : algorithme de Newton à pas fixe.

# %%
def Gradient_F(Oracle, x0, alpha):
    
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables
    
    iter_max = 10000
    gradient_step = alpha
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations

    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)

        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break

        # Direction de descente
        direction = -gradient
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        critere_list.append(critere)
    
    ##### Resultats de l'optimisation

    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start
    
    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %%
def Newton_F(Oracle, x0):
    
    from numpy.linalg import norm
    from numpy.linalg import solve
    from time import process_time
    
    ##### Initialisation des variables    
    
    iter_max = 100
    gradient_step = 1
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient, hessien = Oracle(x)

        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
        
        # Direction de descente
        direction = - solve(hessien, gradient)
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        critere_list.append(critere)
   
    ##### Resultats de l'optimisation
    
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %% [markdown]
# ## I. Résolution du problème primal

# %%
from HydrauliqueP import HydrauliqueP

# %% [markdown]
# ### I.a On écrit les oracles pour le problème primal d'optimisation :
#
# * **OraclePG** : calcul de la fonction et du gradient,
# * **OraclePH** : calcul de la fonction du gradient et du Hessien.

# %%
def F(q_c):
    Q = q0 + np.dot(B, q_c)
    return((1/3)* (np.dot(Q, r * Q * abs(Q)) + np.dot(pr, np.dot(Ar, Q))))

def grad_F(q_c):
    """
    Peut-être rajouter un terme à multiplier pour la règle de la chaîne
    """
    Q = q0 + np.dot(B, q_c)
    return np.dot(np.transpose(B), r*Q*abs(Q)) + np.dot(np.transpose(np.dot(Ar, B)), pr)

def OraclePG(q_c, ind=4):
    if ind == 2 :
        return F(q_c)
    elif ind == 3 :
        return grad_F(q_c)
    elif ind == 4:
        return F(q_c), grad_F(q_c)

# %%
def Hess_F(q_c):
    Q = q0 + B.dot(q_c)
    diago = np.diag(r*np.absolute(Q))
    return(2*np.dot(np.dot(np.transpose(B), diago,), B))

# %%
def OraclePH(q_c, ind=7):
    if ind == 2:
        return F(q_c)
    elif ind == 3:
        return grad_F(q_c)
    elif ind == 4:
        return F(q_c), grad_F(q_c)
    elif ind == 5:
        return Hess_F(q_c)
    elif ind == 6:
        return grad_F(q_c), Hess_F(q_c)
    elif ind == 7:
        return F(q_c), grad_F(q_c), Hess_F(q_c)

# %% [markdown]
# ### On teste la validité des oracles en résolvant le problème :
#
# * **OraclePG** avec la méthode du gradient à pas fixe,
# * **OraclePH** avec la méthode de Newton à pas fixe

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT A PAS FIXE")
copt, gopt, xopt = Gradient_F(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT A PAS FIXE
#
# Iteration : 4144
# Temps CPU : 0.13101377599999964
# Critere optimal : 7.936228345629563
# Norme du gradient : 9.988448180292955e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 2.220446049250313e-16
# Sur les pressions : 9.988398645965901e-07

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE NEWTON A PAS FIXE")
copt, gopt, xopt = Newton_F(OraclePH, x0)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DE NEWTON A PAS FIXE
#
# Iteration : 7
# Temps CPU : 0.003122547000000253
# Critere optimal : 7.936228436722627
# Norme du gradient : 5.3143989138650094e-11
# Verification des equations d'equilibre du reseau
# Sur les debits : 2.220446049250313e-16
# Sur les pressions : 5.0148427077623126e-11

# %% [markdown]
# ### I.b On écrit l'algorithme de recherche linéaire (conditions de Wolfe).

# %%
def Wolfe(alpha, x, D, Oracle):
    
    ##### Coefficients de la recherche lineaire

    omega_1 = 0.1
    omega_2 = 0.9

    alpha_min = 0
    alpha_max = np.inf

    ok = 0
    dltx = 0.00000001

    ##### Algorithme de Fletcher-Lemarechal
    
    # Appel de l'oracle au point initial
    argout = Oracle(x)
    critere_x = argout[0]
    gradient_x = argout[1]

    # Initialisation de l'algorithme
    alpha_n = alpha
    xn = x
    
    # Boucle de calcul du pas
    # xn represente le point pour la valeur courante du pas,
    # xp represente le point pour la valeur precedente du pas.
    while ok == 0:
        
        # Point precedent pour tester l'indistinguabilite
        xp = xn
        
        # Point actuel
        xn = x + alpha_n*D
        critere_xn, gradient_xn = Oracle(xn, ind=4)
        
        # Calcul des conditions de Wolfe
        
        # Si l'on ne vérifie pas la première condition :
        if not critere_xn - critere_x <= omega_1 * alpha_n * np.dot(np.transpose(gradient_x), D):
            alpha_max = alpha_n
            alpha_n = 0.5 * (alpha_max + alpha_min)            
            
            
        else:
            # Si l'on ne vérie pas la seconde condition
            if not np.dot( np.transpose(gradient_xn), D)  >= omega_2 * np.dot(np.transpose(gradient_x), D):
                alpha_min = alpha_n
                if alpha_max == np.inf:
                    alpha_n = 2 * alpha_min
                else :
                    alpha_n = 0.5 * (alpha_max + alpha_min)
                
        # - Si les deux conditions de Wolfe sont verifiees,
        #   poser ok = 1 : on sort alors de la boucle while
            else:
                ok ==1 
            
        # - Sinon, modifier la valeur de alphan et reboucler

        
        # Test d'indistinguabilite
        if norm(xn - xp) < dltx:
            ok = 2

    return alpha_n, ok

# %% [markdown]
# ### I.c On écrit l'algorithme du gradient à pas variable et on le teste

# %%
def Gradient_V(Oracle, x0, alpha):
    
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 1000
    default_gradient_step = alpha
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0
    gradient_step = default_gradient_step
    ##### Boucle sur les iterations

    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)

        # Test de convergence
        gradient_norm = norm(gradient)
        print(k, gradient_k_norm)
        if gradient_norm <= threshold:
            break

        # Direction de descente
        direction = -gradient

        # Mise a jour des variables
        gradient_step, ok = Wolfe(gradient_step, x, direction, Oracle)
        
        x = x + (gradient_step * direction)

        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        critere_list.append(critere)
    
    ##### Resultats de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT A PAS VARIABLE")
copt, gopt, xopt = Gradient_V(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT A PAS VARIABLE
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-5fe23757a6bc> in <module>
#       4 print()
#       5 print("ALGORITHME DU GRADIENT A PAS VARIABLE")
# ----> 6 copt, gopt, xopt = Gradient_V(OraclePG, x0, 1)
#       7 qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
#       8 Verification(A, qopt, zopt, fopt, popt)
#
# <ipython-input-113-eba2fef2acea> in Gradient_V(Oracle, x0, alpha)
#      27         # Test de convergence
#      28         gradient_norm = norm(gradient)
# ---> 29         print(k, gradient_k_norm)
#      30         if gradient_norm <= threshold:
#      31             break
#
# NameError: name 'gradient_k_norm' is not defined

# %% [markdown]
# ### I.d On écrit l'algorithme de gradient conjugué (Polak-Ribière) et on le teste

# %%
def PolakRibiere(Oracle, x0, alpha):
    
    from numpy import dot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 1000
    default_gradient_step = alpha
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0
    
    #### initialisation des variables
    gradient_step = default_gradient_step
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        if k >= 1:
            gradient_k_moins_1 = gradient_k
            direction_k_moins_1 = direction
        
        # Valeur du critere et du gradient
        critere_k, gradient_k = Oracle(x)

        # Test de convergence
        gradient_k_norm = norm(gradient_k)
        print(k, gradient_k_norm)
        if gradient_k_norm <= threshold:
            break

        # Direction de descente
        if k == 0:
            direction = - gradient_k
        else:
            Beta_k_moins_1 = np.dot(gradient_k - gradient_k_moins_1, gradient_k) / (norm(gradient_k_moins_1) ** 2)
            direction = -gradient_k + Beta_k_moins_1 * direction_k_moins_1

        # Mise a jour des variables
        gradient_step, ok = Wolfe(gradient_step, x, direction, Oracle)
        
        x = x + (gradient_step * direction)

        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_k_norm)
        gradient_step_list.append(gradient_step)
        critere_list.append(critere_k)
    
    # Resultat de l'optimisation
    critere_opt = critere_k
    gradient_opt = gradient_k
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt = PolakRibiere(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT CONJUGUE
# 0 497.82665366865564
# 1 158.46535828371452
# 2 167.16319292666947
# 3 65.32359850913264
# 4 54.598576418618904
# 5 38.23677471206921
# 6 34.0964693257804
# 7 29.114498718478004
# 8 23.91002345946897
# 9 20.61164190200959
# 10 18.076850140662163
# 11 16.122662732919782
# 12 13.84492258696815
# 13 11.541941142688339
# 14 9.984097820808113
# 15 8.984857406472901
# 16 8.2143654298207
# 17 7.563387529406942
# 18 7.007754494963354
# 19 6.514792102387187
# 20 6.0764728780302555
# 21 5.680412823830185
# 22 5.323761640998696
# 23 4.999420130074649
# 24 4.705207605699725
# 25 4.436561468823291
# 26 4.191712748076781
# 27 3.96759462404803
# 28 3.762720136782463
# 29 3.5749182789572975
# 30 3.4029093071763463
# 31 3.24508208772211
# 32 3.100325623858118
# 33 2.9673964675641056
# 34 2.845329575802686
# 35 2.7331355705065308
# 36 2.629979110526366
# 37 2.5350555658534044
# 38 2.447645946774415
# 39 2.6311404504124796
# 40 2.208370529273669
# 41 2.088554610483924
# 42 4.928197611910359
# 43 4.476288037118175
# 44 6.459778076016756
# 45 6.459778350283006
# 46 6.459776927053035
# 47 6.459774080594508
# 48 6.459768387681732
# 49 6.4597570018735215
# 50 6.45973423032635
# 51 5.7178601287240545
# 52 4.595843356838689
# 53 4.128444472724975
# 54 4.128437616174833
# 55 4.1284338704458055
# 56 4.128431997582581
# 57 4.128431061151175
# 58 4.128430592935502
# 59 4.128430358827737
# 60 4.128430241773811
# 61 4.128430183246814
# 62 4.128430153983353
# 63 4.128430139351615
# 64 4.128430132035738
# 65 4.1284301283778095
# 66 4.12843012654884
# 67 4.128430125634383
# 68 4.128430125177154
# 69 4.1284301249484745
# 70 4.1284301248341775
# 71 4.128430124777038
# 72 4.1284301246627235
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.1102230246251565e-16
# Sur les pressions : 2.2595047128684804

# %% [markdown]
# ### I.e On écrit l'algorithme de quasi-Newton (BFGS) et on le teste

# %%
def BFGS(Oracle, x0):
    
    from numpy import dot
    from numpy import eye
    from numpy import outer
    from numpy import vdot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 250
    default_gradient_step = 1
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # ---> A COMPLETER
        # ---> A COMPLETER
        #
        # Attention a l'initialisation de l'algorithme !
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt = BFGS(OraclePG, x0)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)

# %% [markdown]
# ### I.f On écrit l'algorithme de Newton à pas variable et on le teste

# %%
def Newton_V(Oracle, x0):
    
    from numpy.linalg import norm
    from numpy.linalg import solve
    from time import process_time
    
    ##### Initialisation des variables  
    
    iter_max = 100
    default_gradient_step = 1
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # ---> A COMPLETER
        # ---> A COMPLETER
           
    ##### Resultats de l'optimisation
    
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_V(OraclePH, x0)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)

# %% [markdown]
# ## II. Résolution du problème dual

# %%
from HydrauliqueD import HydrauliqueD

# %% [markdown]
# ### II.a On écrit les oracles pour le problème dual d'optimisation :
#
# * **OracleDG** : calcul de la fonction et du gradient,
# * **OracleDH** : calcul de la fonction du gradient et du Hessien.

# %%
def OracleDG(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient

# %%
def OracleDH(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %% [markdown]
# ### II.b On exécute tous les algorithmes d'optimisation déjà écrits

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DU GRADIENT A PAS VARIABLE")
copt, gopt, xopt = Gradient_V(OracleDG, x0, 5)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt = PolakRibiere(OracleDG, x0, 5)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt = BFGS(OracleDG, x0)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_V(OracleDH, x0)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %% [markdown]
# ## III. Résolution de grands réseaux (facultatif)

# %% [markdown]
# ### On charge dans l'environnement les données du problème
#
# Ces données correspondent à un réseau de taille paramétrable.

# %%
from Probleme_P import *
from Structures_S import *

# %% [markdown]
# ### III.a On écrit des oracles primal et dual avec Hessien creux

# %%
def OraclePHS(qc):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %%
def OracleDHS(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %% [markdown]
# ### III.b On écrit un algorithme de Newton exploitant le creux

# %%
def Newton_S(Oracle, x0):
    
    from numpy.linalg import norm
    from scipy.sparse.linalg import spsolve
    from time import process_time
    
    ##### Initialisation des variables  
    
    iter_max = 100
    default_gradient_step = 1
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # ---> A COMPLETER
        # ---> A COMPLETER
           
    ##### Resultats de l'optimisation
    
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %% [markdown]
# ### III.c On résoud le problème dans le primal et dans le dual

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL DE GRANDE TAILLE")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_S(OraclePHS, x0)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL DE GRANDE TAILLE")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_S(OracleDHS, x0)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)
